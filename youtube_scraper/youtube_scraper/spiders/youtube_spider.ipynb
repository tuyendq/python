# %%
# !uv add scrapy
import scrapy
print(scrapy.__version__)
# Out:
# ...
# Resolved 40 packages in 1ms
# Audited 38 packages in 0.05ms
# 2.12.0

# %%
from scrapy.http import Response

# %%
url = "https://www.youtube.com/@summaryversion/videos"
response = Response(url=url)

# %%
dir(response)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_body',
#  '_set_body',
#  '_set_url',
#  '_url',
#  'attributes',
#  'body',
#  'cb_kwargs',
#  'certificate',
#  'copy',
#  'css',
#  'flags',
#  'follow',
#  'follow_all',
#  'headers',
#  'ip_address',
#  'jmespath',
#  'meta',
#  'protocol',
#  'replace',
#  'request',
#  'status',
#  'text',
#  'url',
#  'urljoin',
#  'xpath']

# %%
response.css('title')
# Out:
# ---------------------------------------------------------------------------
# NotSupported                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 response.css('title')
#
# File C:\projects\python\.venv\Lib\site-packages\scrapy\http\response\__init__.py:170, in Response.css(self, *a, **kw)
#     166 def css(self, *a: Any, **kw: Any) -> SelectorList:
#     167     """Shortcut method implemented only by responses whose content
#     168     is text (subclasses of TextResponse).
#     169     """
# --> 170     raise NotSupported("Response content isn't text")
#
# NotSupported: Response content isn't text
