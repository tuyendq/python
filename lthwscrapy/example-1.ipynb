# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in d:\python\python37\lib\site-packages (2.9.0)
# Requirement already satisfied: Twisted>=18.9.0 in d:\python\python37\lib\site-packages (from scrapy) (23.8.0)
# Requirement already satisfied: cryptography>=3.4.6 in d:\python\python37\lib\site-packages (from scrapy) (35.0.0)
# Requirement already satisfied: cssselect>=0.9.1 in d:\python\python37\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in d:\python\python37\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in d:\python\python37\lib\site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in d:\python\python37\lib\site-packages (from scrapy) (21.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in d:\python\python37\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in d:\python\python37\lib\site-packages (from scrapy) (21.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in d:\python\python37\lib\site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in d:\python\python37\lib\site-packages (from scrapy) (6.1)
# Requirement already satisfied: protego>=0.1.15 in d:\python\python37\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in d:\python\python37\lib\site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in d:\python\python37\lib\site-packages (from scrapy) (58.3.0)
# Requirement already satisfied: packaging in d:\python\python37\lib\site-packages (from scrapy) (20.3)
# Requirement already satisfied: tldextract in d:\python\python37\lib\site-packages (from scrapy) (4.0.0)
# Requirement already satisfied: lxml>=4.3.0 in d:\python\python37\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in d:\python\python37\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in d:\python\python37\lib\site-packages (from cryptography>=3.4.6->scrapy) (1.14.1)
# Requirement already satisfied: jmespath>=0.9.5 in d:\python\python37\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: typing-extensions in d:\python\python37\lib\site-packages (from parsel>=1.5.0->scrapy) (4.7.1)
# Requirement already satisfied: six>=1.5.2 in d:\python\python37\lib\site-packages (from pyOpenSSL>=21.0.0->scrapy) (1.15.0)
# Requirement already satisfied: attrs>=19.1.0 in d:\python\python37\lib\site-packages (from service-identity>=18.1.0->scrapy) (24.2.0)
# Requirement already satisfied: pyasn1-modules in d:\python\python37\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in d:\python\python37\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: automat>=0.8.0 in d:\python\python37\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: constantly>=15.1 in d:\python\python37\lib\site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: hyperlink>=17.1.1 in d:\python\python37\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=22.10.0 in d:\python\python37\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in d:\python\python37\lib\site-packages (from Twisted>=18.9.0->scrapy) (1.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\python\python37\lib\site-packages (from packaging->scrapy) (2.4.6)
# Requirement already satisfied: idna in d:\python\python37\lib\site-packages (from tldextract->scrapy) (3.3)
# Requirement already satisfied: requests>=2.1.0 in d:\python\python37\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in d:\python\python37\lib\site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in d:\python\python37\lib\site-packages (from tldextract->scrapy) (3.0.12)
# Requirement already satisfied: importlib-metadata in d:\python\python37\lib\site-packages (from attrs>=19.1.0->service-identity>=18.1.0->scrapy) (1.5.0)
# Requirement already satisfied: pycparser in d:\python\python37\lib\site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\python37\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python\python37\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python\python37\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in d:\python\python37\lib\site-packages (from importlib-metadata->attrs>=19.1.0->service-identity>=18.1.0->scrapy) (3.1.0)

# %%
from scrapy.selector import Selector
from scrapy.http import HtmlResponse

# %%
response = HtmlResponse(url="https://example.com")
type(response)
# Out:
# scrapy.http.response.html.HtmlResponse

# %%
dir(response)
# Out:
# ['_DEFAULT_ENCODING',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_auto_detect_fun',
#  '_body',
#  '_body_declared_encoding',
#  '_body_inferred_encoding',
#  '_bom_encoding',
#  '_cached_benc',
#  '_cached_decoded_json',
#  '_cached_selector',
#  '_cached_ubody',
#  '_declared_encoding',
#  '_encoding',
#  '_headers_encoding',
#  '_set_body',
#  '_set_url',
#  '_url',
#  'attributes',
#  'body',
#  'cb_kwargs',
#  'certificate',
#  'copy',
#  'css',
#  'encoding',
#  'flags',
#  'follow',
#  'follow_all',
#  'headers',
#  'ip_address',
#  'jmespath',
#  'json',
#  'meta',
#  'protocol',
#  'replace',
#  'request',
#  'selector',
#  'status',
#  'text',
#  'url',
#  'urljoin',
#  'xpath']

# %%
response.encoding
# Out:
# 'cp1252'
